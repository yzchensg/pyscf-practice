# %% [markdown]
# ## A new binding model

# %%
import joblib
from joblib import Parallel, delayed
from pyscf import gto, scf, dft
import datetime
import time
import psutil
import glob
import numpy as np
import json
import tensorflow as tf
from tqdm import tqdm
import sys
from sklearn.model_selection import train_test_split
from scipy import stats
from scipy.stats import kde
from matplotlib import pyplot as plt
from matplotlib.lines import Line2D
import random
import seaborn as sns
from training_utils import *

np.random.seed(0)
random.seed(0)
# Out:
# 2025-08-28 12:04:16.530500: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-28 12:04:16.538584: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756397056.547129    6106 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756397056.549638    6106 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1756397056.556594    6106 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1756397056.556611    6106 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1756397056.556612    6106 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1756397056.556613    6106 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-28 12:04:16.559688: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 20
#      18 import random
#      19 import seaborn as sns
# ---> 20 from training_utils import *
#      22 np.random.seed(0)
#      23 random.seed(0)
#
# ModuleNotFoundError: No module named 'training_utils'
